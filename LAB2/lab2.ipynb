# %%
# Design a Vehicle Rental System using OOP.
# Requirements:
# 1. Create a class Vehicle
# 2. Attributes: vehicle_id, brand, rent_per_day
# 3. Methods: display_details(), calculate_rent(days)
# 4. Create at least two vehicle objects
# 5. Calculate rent for different days
class vehical:
    def __init__(self,vehical_id,brand,rent_per_day):
        self.vehical_id=vehical_id
        self.brand=brand
        self.rent_per_day=rent_per_day
    def display_deatails(self):
        print("vehical id: ",self.vehical_id)
        print("brand: ",self.brand)
    def calculate_rent(self,days):
        print("rent calculated for ",self.brand ," is :", self.rent_per_day*days)
    
o1=vehical("1234","toyota",1000)
o2=vehical("2234","bike",200)
o1.calculate_rent(5)
o2.calculate_rent(3)
# Out:
# rent calculated for  toyota  is : 5000
# rent calculated for  bike  is : 600

# %%
# Design an Employee Payroll System using inheritance.
# Requirements:
# 1. Base class Employee (name, emp_id)
# 2. Child classes:
# - FullTimeEmployee (monthly_salary)
# - PartTimeEmployee (hours_worked, hourly_rate)
# 3. Override calculate_salary() method
# 4. Create objects and display salary
class employee:
    def __init__(self,name,emp_id):
        self.name=name
        self.emp_id=emp_id
    def calculate_salary(self):
        pass 

class FullTimeEmployee(employee):
    def __init__(self,name,emp_id,monthly_salary):
        super().__init__(name,emp_id)
        self.monthly_salary=monthly_salary
    def calculate_salary(self):
        return self.monthly_salary
    
class PartTimeEmployee(employee):
        def __init__(self,name,emp_id,hours_worked,hourly_rate):
             super().__init__(name,emp_id)
             self.hours_worked=hours_worked
             self.hourly_rate=hourly_rate

        def calculate_salary(self):
            return self.hours_worked * self.hourly_rate
        
ft = FullTimeEmployee("Ali", 101, 50000)
pt = PartTimeEmployee("Sara", 102, 80, 500)

print("Full-Time Employee Salary:", ft.calculate_salary())
print("Part-Time Employee Salary:", pt.calculate_salary())
# Out:
# Full-Time Employee Salary: 50000
# Part-Time Employee Salary: 40000

# %%
# Design a Student Result System using encapsulation.
# Requirements:
# 1. Private attribute __marks
# 2. Methods: set_marks(), get_marks(), calculate_grade()
# 3. Create at least two student objects
class student_result:
    __marks=0
    def set_marks(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    
s1=student_result()
s2=student_result()
s1.set_marks(100)
s2.set_marks(59)
print("marks of 1st student is: ",s1.get_marks())
print("marks of 2nd student is: ",s2.get_marks())
# Out:
# marks of 1st student is:  100
# marks of 2nd student is:  59
